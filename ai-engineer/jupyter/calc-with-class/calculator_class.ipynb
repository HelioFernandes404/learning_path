# %% [markdown]
# # Mini-exercício mental (sem código)
# Responda mentalmente:
#     A sua calculadora é:
#     descartável (calcula e esquece)?
#     ou mantém resultado?
# Quem decide qual operação será feita:
#     o usuário?
#     o menu?
#     ou a calculadora?
# Se amanhã você quiser uma calculadora científica,
# o que mudaria:
#     os métodos?
#     o estado?
#     ou ambos?
#
# Minha Calculadora v1
# - descartável (calcula e esquece)
# - Quem decide e o usuário
# - Ambos.
#
# ele faz seguinte oprecoes:
# somar
# subtrair
# multiplicar
# dividir

# %%
class Calculadora:
    """"""
    def soma(a , b):
        return a + b 
    def subtrair(a , b):
        """Minuendo e subtraendo simples"""
        if (b > a):
            return print("ERRROR: O valor A (Minuendo) precisa ser maior que o B (subtraendo)")
        return a - b 
    def multiplicar(a , b): 
        return a * b
    def dividir(dividendo, divisor):
        """return: quociente"""
        return dividendo / divisor

# %%
print(Calculadora.soma(1, 10))
print(Calculadora.subtrair(1, 10))
print(Calculadora.multiplicar(1, 10))
print(Calculadora.dividir(1, 10))
# Out:
# 11
# ERRROR: O valor A (Minuendo) precisa ser maior que o B (subtraendo)
# None
# 10
# 0.1
